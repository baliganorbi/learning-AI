# %% [markdown]
# ## Different demos with Local LLM

# %% [markdown]
# ### Llmaindex with Ollama
#
# Examples on how to use LlamaIndex local LLM (Ollama - gemm3).

# %% [markdown]
# #### Install necessary packages

# %%
# !pip install -U llama-index-llms-ollama llama-index ollama
# Out:
# Requirement already satisfied: llama-index-llms-ollama in ./.venv/lib/python3.12/site-packages (0.9.1)
# Requirement already satisfied: llama-index in ./.venv/lib/python3.12/site-packages (0.14.13)
# Requirement already satisfied: ollama in ./.venv/lib/python3.12/site-packages (0.6.1)
# Requirement already satisfied: llama-index-core<0.15,>=0.14.5 in ./.venv/lib/python3.12/site-packages (from llama-index-llms-ollama) (0.14.13)
# Requirement already satisfied: aiohttp<4,>=3.8.6 in ./.venv/lib/python3.12/site-packages (from llama-index-core<0.15,>=0.14.5->llama-index-llms-ollama) (3.13.3)
# Requirement already satisfied: aiosqlite in ./.venv/lib/python3.12/site-packages (from llama-index-core<0.15,>=0.14.5->llama-index-llms-ollama) (0.22.1)
# Requirement already satisfied: banks<3,>=2.2.0 in ./.venv/lib/python3.12/site-packages (from llama-index-core<0.15,>=0.14.5->llama-index-llms-ollama) (2.4.0)
# Requirement already satisfied: dataclasses-json in ./.venv/lib/python3.12/site-packages (from llama-index-core<0.15,>=0.14.5->llama-index-llms-ollama) (0.6.7)
# Requirement already satisfied: deprecated>=1.2.9.3 in ./.venv/lib/python3.12/site-packages (from llama-index-core<0.15,>=0.14.5->llama-index-llms-ollama) (1.2.18)
# Requirement already satisfied: dirtyjson<2,>=1.0.8 in ./.venv/lib/python3.12/site-packages (from llama-index-core<0.15,>=0.14.5->llama-index-llms-ollama) (1.0.8)
# Requirement already satisfied: filetype<2,>=1.2.0 in ./.venv/lib/python3.12/site-packages (from llama-index-core<0.15,>=0.14.5->llama-index-llms-ollama) (1.2.0)
# Requirement already satisfied: fsspec>=2023.5.0 in ./.venv/lib/python3.12/site-packages (from llama-index-core<0.15,>=0.14.5->llama-index-llms-ollama) (2026.2.0)
# Requirement already satisfied: httpx in ./.venv/lib/python3.12/site-packages (from llama-index-core<0.15,>=0.14.5->llama-index-llms-ollama) (0.28.1)
# Requirement already satisfied: llama-index-workflows!=2.9.0,<3,>=2 in ./.venv/lib/python3.12/site-packages (from llama-index-core<0.15,>=0.14.5->llama-index-llms-ollama) (2.14.0)
# Requirement already satisfied: nest-asyncio<2,>=1.5.8 in ./.venv/lib/python3.12/site-packages (from llama-index-core<0.15,>=0.14.5->llama-index-llms-ollama) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in ./.venv/lib/python3.12/site-packages (from llama-index-core<0.15,>=0.14.5->llama-index-llms-ollama) (3.6.1)
# Requirement already satisfied: nltk>3.8.1 in ./.venv/lib/python3.12/site-packages (from llama-index-core<0.15,>=0.14.5->llama-index-llms-ollama) (3.9.2)
# Requirement already satisfied: numpy in ./.venv/lib/python3.12/site-packages (from llama-index-core<0.15,>=0.14.5->llama-index-llms-ollama) (2.4.2)
# Requirement already satisfied: pillow>=9.0.0 in ./.venv/lib/python3.12/site-packages (from llama-index-core<0.15,>=0.14.5->llama-index-llms-ollama) (12.1.0)
# Requirement already satisfied: platformdirs in ./.venv/lib/python3.12/site-packages (from llama-index-core<0.15,>=0.14.5->llama-index-llms-ollama) (4.5.1)
# Requirement already satisfied: pydantic>=2.8.0 in ./.venv/lib/python3.12/site-packages (from llama-index-core<0.15,>=0.14.5->llama-index-llms-ollama) (2.12.5)
# Requirement already satisfied: pyyaml>=6.0.1 in ./.venv/lib/python3.12/site-packages (from llama-index-core<0.15,>=0.14.5->llama-index-llms-ollama) (6.0.3)
# Requirement already satisfied: requests>=2.31.0 in ./.venv/lib/python3.12/site-packages (from llama-index-core<0.15,>=0.14.5->llama-index-llms-ollama) (2.32.5)
# Requirement already satisfied: setuptools>=80.9.0 in ./.venv/lib/python3.12/site-packages (from llama-index-core<0.15,>=0.14.5->llama-index-llms-ollama) (80.10.2)
# Requirement already satisfied: sqlalchemy>=1.4.49 in ./.venv/lib/python3.12/site-packages (from sqlalchemy[asyncio]>=1.4.49->llama-index-core<0.15,>=0.14.5->llama-index-llms-ollama) (2.0.46)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.2.0 in ./.venv/lib/python3.12/site-packages (from llama-index-core<0.15,>=0.14.5->llama-index-llms-ollama) (9.1.3)
# Requirement already satisfied: tiktoken>=0.7.0 in ./.venv/lib/python3.12/site-packages (from llama-index-core<0.15,>=0.14.5->llama-index-llms-ollama) (0.12.0)
# Requirement already satisfied: tqdm<5,>=4.66.1 in ./.venv/lib/python3.12/site-packages (from llama-index-core<0.15,>=0.14.5->llama-index-llms-ollama) (4.67.3)
# Requirement already satisfied: typing-extensions>=4.5.0 in ./.venv/lib/python3.12/site-packages (from llama-index-core<0.15,>=0.14.5->llama-index-llms-ollama) (4.15.0)
# Requirement already satisfied: typing-inspect>=0.8.0 in ./.venv/lib/python3.12/site-packages (from llama-index-core<0.15,>=0.14.5->llama-index-llms-ollama) (0.9.0)
# Requirement already satisfied: wrapt in ./.venv/lib/python3.12/site-packages (from llama-index-core<0.15,>=0.14.5->llama-index-llms-ollama) (1.17.3)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in ./.venv/lib/python3.12/site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15,>=0.14.5->llama-index-llms-ollama) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in ./.venv/lib/python3.12/site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15,>=0.14.5->llama-index-llms-ollama) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in ./.venv/lib/python3.12/site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15,>=0.14.5->llama-index-llms-ollama) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in ./.venv/lib/python3.12/site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15,>=0.14.5->llama-index-llms-ollama) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in ./.venv/lib/python3.12/site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15,>=0.14.5->llama-index-llms-ollama) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in ./.venv/lib/python3.12/site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15,>=0.14.5->llama-index-llms-ollama) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in ./.venv/lib/python3.12/site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15,>=0.14.5->llama-index-llms-ollama) (1.22.0)
# Requirement already satisfied: griffe in ./.venv/lib/python3.12/site-packages (from banks<3,>=2.2.0->llama-index-core<0.15,>=0.14.5->llama-index-llms-ollama) (1.15.0)
# Requirement already satisfied: jinja2 in ./.venv/lib/python3.12/site-packages (from banks<3,>=2.2.0->llama-index-core<0.15,>=0.14.5->llama-index-llms-ollama) (3.1.6)
# Requirement already satisfied: llama-index-instrumentation>=0.1.0 in ./.venv/lib/python3.12/site-packages (from llama-index-workflows!=2.9.0,<3,>=2->llama-index-core<0.15,>=0.14.5->llama-index-llms-ollama) (0.4.2)
# Requirement already satisfied: idna>=2.0 in ./.venv/lib/python3.12/site-packages (from yarl<2.0,>=1.17.0->aiohttp<4,>=3.8.6->llama-index-core<0.15,>=0.14.5->llama-index-llms-ollama) (3.11)
# Requirement already satisfied: llama-index-cli<0.6,>=0.5.0 in ./.venv/lib/python3.12/site-packages (from llama-index) (0.5.3)
# Requirement already satisfied: llama-index-embeddings-openai<0.6,>=0.5.0 in ./.venv/lib/python3.12/site-packages (from llama-index) (0.5.1)
# Requirement already satisfied: llama-index-indices-managed-llama-cloud>=0.4.0 in ./.venv/lib/python3.12/site-packages (from llama-index) (0.9.4)
# Requirement already satisfied: llama-index-llms-openai<0.7,>=0.6.0 in ./.venv/lib/python3.12/site-packages (from llama-index) (0.6.18)
# Requirement already satisfied: llama-index-readers-file<0.6,>=0.5.0 in ./.venv/lib/python3.12/site-packages (from llama-index) (0.5.6)
# Requirement already satisfied: llama-index-readers-llama-parse>=0.4.0 in ./.venv/lib/python3.12/site-packages (from llama-index) (0.5.1)
# Requirement already satisfied: openai>=1.1.0 in ./.venv/lib/python3.12/site-packages (from llama-index-embeddings-openai<0.6,>=0.5.0->llama-index) (2.17.0)
# Requirement already satisfied: beautifulsoup4<5,>=4.12.3 in ./.venv/lib/python3.12/site-packages (from llama-index-readers-file<0.6,>=0.5.0->llama-index) (4.14.3)
# Requirement already satisfied: defusedxml>=0.7.1 in ./.venv/lib/python3.12/site-packages (from llama-index-readers-file<0.6,>=0.5.0->llama-index) (0.7.1)
# Requirement already satisfied: pandas<3,>=2.0.0 in ./.venv/lib/python3.12/site-packages (from llama-index-readers-file<0.6,>=0.5.0->llama-index) (2.3.3)
# Requirement already satisfied: pypdf<7,>=6.1.3 in ./.venv/lib/python3.12/site-packages (from llama-index-readers-file<0.6,>=0.5.0->llama-index) (6.6.2)
# Requirement already satisfied: striprtf<0.0.27,>=0.0.26 in ./.venv/lib/python3.12/site-packages (from llama-index-readers-file<0.6,>=0.5.0->llama-index) (0.0.26)
# Requirement already satisfied: soupsieve>=1.6.1 in ./.venv/lib/python3.12/site-packages (from beautifulsoup4<5,>=4.12.3->llama-index-readers-file<0.6,>=0.5.0->llama-index) (2.8.3)
# Requirement already satisfied: anyio<5,>=3.5.0 in ./.venv/lib/python3.12/site-packages (from openai>=1.1.0->llama-index-embeddings-openai<0.6,>=0.5.0->llama-index) (4.12.1)
# Requirement already satisfied: distro<2,>=1.7.0 in ./.venv/lib/python3.12/site-packages (from openai>=1.1.0->llama-index-embeddings-openai<0.6,>=0.5.0->llama-index) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in ./.venv/lib/python3.12/site-packages (from openai>=1.1.0->llama-index-embeddings-openai<0.6,>=0.5.0->llama-index) (0.13.0)
# Requirement already satisfied: sniffio in ./.venv/lib/python3.12/site-packages (from openai>=1.1.0->llama-index-embeddings-openai<0.6,>=0.5.0->llama-index) (1.3.1)
# Requirement already satisfied: certifi in ./.venv/lib/python3.12/site-packages (from httpx->llama-index-core<0.15,>=0.14.5->llama-index-llms-ollama) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in ./.venv/lib/python3.12/site-packages (from httpx->llama-index-core<0.15,>=0.14.5->llama-index-llms-ollama) (1.0.9)
# Requirement already satisfied: h11>=0.16 in ./.venv/lib/python3.12/site-packages (from httpcore==1.*->httpx->llama-index-core<0.15,>=0.14.5->llama-index-llms-ollama) (0.16.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./.venv/lib/python3.12/site-packages (from pandas<3,>=2.0.0->llama-index-readers-file<0.6,>=0.5.0->llama-index) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in ./.venv/lib/python3.12/site-packages (from pandas<3,>=2.0.0->llama-index-readers-file<0.6,>=0.5.0->llama-index) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in ./.venv/lib/python3.12/site-packages (from pandas<3,>=2.0.0->llama-index-readers-file<0.6,>=0.5.0->llama-index) (2025.3)
# Requirement already satisfied: annotated-types>=0.6.0 in ./.venv/lib/python3.12/site-packages (from pydantic>=2.8.0->llama-index-core<0.15,>=0.14.5->llama-index-llms-ollama) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in ./.venv/lib/python3.12/site-packages (from pydantic>=2.8.0->llama-index-core<0.15,>=0.14.5->llama-index-llms-ollama) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in ./.venv/lib/python3.12/site-packages (from pydantic>=2.8.0->llama-index-core<0.15,>=0.14.5->llama-index-llms-ollama) (0.4.2)
# Requirement already satisfied: llama-cloud==0.1.35 in ./.venv/lib/python3.12/site-packages (from llama-index-indices-managed-llama-cloud>=0.4.0->llama-index) (0.1.35)
# Requirement already satisfied: llama-parse>=0.5.0 in ./.venv/lib/python3.12/site-packages (from llama-index-readers-llama-parse>=0.4.0->llama-index) (0.6.54)
# Requirement already satisfied: llama-cloud-services>=0.6.54 in ./.venv/lib/python3.12/site-packages (from llama-parse>=0.5.0->llama-index-readers-llama-parse>=0.4.0->llama-index) (0.6.54)
# Requirement already satisfied: click<9,>=8.1.7 in ./.venv/lib/python3.12/site-packages (from llama-cloud-services>=0.6.54->llama-parse>=0.5.0->llama-index-readers-llama-parse>=0.4.0->llama-index) (8.3.1)
# Requirement already satisfied: python-dotenv<2,>=1.0.1 in ./.venv/lib/python3.12/site-packages (from llama-cloud-services>=0.6.54->llama-parse>=0.5.0->llama-index-readers-llama-parse>=0.4.0->llama-index) (1.2.1)
# Requirement already satisfied: joblib in ./.venv/lib/python3.12/site-packages (from nltk>3.8.1->llama-index-core<0.15,>=0.14.5->llama-index-llms-ollama) (1.5.3)
# Requirement already satisfied: regex>=2021.8.3 in ./.venv/lib/python3.12/site-packages (from nltk>3.8.1->llama-index-core<0.15,>=0.14.5->llama-index-llms-ollama) (2026.1.15)
# Requirement already satisfied: six>=1.5 in ./.venv/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas<3,>=2.0.0->llama-index-readers-file<0.6,>=0.5.0->llama-index) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in ./.venv/lib/python3.12/site-packages (from requests>=2.31.0->llama-index-core<0.15,>=0.14.5->llama-index-llms-ollama) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./.venv/lib/python3.12/site-packages (from requests>=2.31.0->llama-index-core<0.15,>=0.14.5->llama-index-llms-ollama) (2.6.3)
# Requirement already satisfied: greenlet>=1 in ./.venv/lib/python3.12/site-packages (from sqlalchemy>=1.4.49->sqlalchemy[asyncio]>=1.4.49->llama-index-core<0.15,>=0.14.5->llama-index-llms-ollama) (3.3.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in ./.venv/lib/python3.12/site-packages (from typing-inspect>=0.8.0->llama-index-core<0.15,>=0.14.5->llama-index-llms-ollama) (1.1.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in ./.venv/lib/python3.12/site-packages (from dataclasses-json->llama-index-core<0.15,>=0.14.5->llama-index-llms-ollama) (3.26.2)
# Requirement already satisfied: packaging>=17.0 in ./.venv/lib/python3.12/site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->llama-index-core<0.15,>=0.14.5->llama-index-llms-ollama) (26.0)
# Requirement already satisfied: colorama>=0.4 in ./.venv/lib/python3.12/site-packages (from griffe->banks<3,>=2.2.0->llama-index-core<0.15,>=0.14.5->llama-index-llms-ollama) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in ./.venv/lib/python3.12/site-packages (from jinja2->banks<3,>=2.2.0->llama-index-core<0.15,>=0.14.5->llama-index-llms-ollama) (3.0.3)

# %% [markdown]
# #### Basic usage

# %% [markdown]
# 1. Completion

# %%
from llama_index.llms.ollama import Ollama

windows_host_ip = "172.17.80.1"
ollama_port = 11434
gemma3 = Ollama(
    model="gemma3", 
    base_url=f"http://{windows_host_ip}:{ollama_port}", 
    request_timeout=100.0)

resp = gemma3.complete("Summarize in 2 sentences who Paul Graham is.")
print(resp)
# Out:
# Paul Graham is a highly influential American computer scientist, philosopher, and venture capitalist best known for his role in founding Y Combinator, a startup accelerator. He’s also a prolific writer and essayist, particularly known for his ideas on technology, hacking, and the importance of building simple, elegant systems.

# %% [markdown]
# 2. Chat message

# %%
from llama_index.core.llms import ChatMessage

messages = [
    ChatMessage(
        role="system", content="You are a pirate with a colorful personality"
    ),
    ChatMessage(role="user", content="What is your name?"),
]

resp = gemma3.chat(messages)
print(resp)
# Out:
# assistant: Blast yer eyes, lad! Ye want to know me name, do ye? Well, they call me One-Eyed Silas, though some just shout “Silas, ye scurvy dog!” which, frankly, I’ve grown rather fond of.  It's a name earned, ye see. Lost me eye to a particularly grumpy kraken – long story, best told with a tankard o' rum!
#
# So, aye, Silas it is.  Silas Blackheart, at yer service... or perhaps at yer demise, depending on how ye treat a pirate!  Now, what brings ye to these waters, eh?  Don’t be standin' there gawkin', a fresh face!

# %% [markdown]
# 3. Streaming

# %%
resp = gemma3.stream_complete("Using Gen AI SDK or Llmaindex how to decide When to use complete vs chat?")

for r in resp:
    print(r.delta, end="")
# Out:
# Okay, let's break down how to decide between using a complete retrieval vs. a chat-based approach with Gen AI SDKs (like Cohere's) or LLM indexes (like LlamaIndex). The choice depends heavily on the *type of question* you're trying to answer and the *desired level of control and nuance*.
#
# **1. Understanding the Approaches**
#
# * **Complete Retrieval (Vector Search + LLM):**
#     * **How it Works:** You create vector embeddings of your documents. These embeddings represent the *meaning* of the text. You then use a vector search engine (like Pinecone, ChromaDB, Weaviate) to find the *most similar* embeddings to a user's query.  Finally, the most relevant documents are fed to a Large Language Model (LLM) to generate a response.
#     * **Strengths:**
#         * **Precision:** Excellent for factual questions where the answer is directly contained within the retrieved documents.
#         * **Scalability:** Vector search is highly efficient for large document sets.
#         * **Contextualized by Specific Documents:** The LLM operates within the precise context provided by the retrieved documents – minimizing hallucination.
#     * **Weaknesses:**
#         * **Limited Reasoning:** The LLM doesn't have a broader understanding beyond the documents it's given. It can struggle with complex, multi-step reasoning or synthesis.
#         * **Requires High-Quality Documents:**  The effectiveness is *highly* dependent on the quality of the documents you're indexing.  Poorly structured, ambiguous documents will lead to poor retrieval.
#
# * **Chat-Based (LLM-First with Indexing):**
#     * **How it Works:** The user's query is directly sent to the LLM.  LlamaIndex (or similar) often creates an index to help *organize* the knowledge, but the index primarily serves as a context boost for the LLM's response.  It’s about adding useful information to the prompt rather than using retrieval in the traditional sense.
#     * **Strengths:**
#         * **Flexibility & Reasoning:** The LLM can perform more complex reasoning, synthesize information, and generate more creative responses.
#         * **Conversational Flow:**  Easier to build a conversational experience (remembering the context of the conversation).
#         * **Less Reliance on Document Perfection:** The LLM can often handle slightly less structured or less perfect documents.
#     * **Weaknesses:**
#         * **Hallucination Risk:**  The LLM can “hallucinate” – confidently provide incorrect information, especially if the provided context isn’t fully sufficient.
#         * **Cost:** LLM inference (generating responses) is typically more expensive than simple vector search.
#         * **Requires Prompt Engineering:** Getting the LLM to generate the *best* response requires careful prompt engineering.
#
# **2. When to Use Which: A Decision Guide**
#
# | **Question Type** | **Desired Outcome** | **Best Approach** | **Why** |
# |---|---|---|---|
# | **Factual, Direct Questions** (e.g., "What is the capital of France?") | Precise, verifiable answer | Complete Retrieval (Vector Search + LLM) | Accuracy is paramount. You want the LLM to simply extract the answer from the relevant document. |
# | **Complex Questions Requiring Synthesis & Reasoning** (e.g., "Compare and contrast the economic policies of Reagan and Thatcher.") |  A nuanced, well-reasoned answer | Chat-Based (LLM-First with Indexing) | The LLM’s reasoning capabilities are needed to draw connections between documents. |
# | **Questions with Multiple Relevant Documents** (e.g., "Summarize these research papers on climate change.") |  A cohesive summary drawing from multiple sources |  Hybrid: Use Complete Retrieval to identify relevant snippets *then* use Chat to synthesize them. |  Retrieval helps you narrow the focus, and the Chat provides the synthesis. |
# | **Questions About a Specific Person or Entity** (e.g., "What are Elon Musk's latest ventures?") |  A detailed account of their activities | Complete Retrieval -  You'd likely want to index biographies, news articles, and official statements. |  You need to pull all relevant information together, not just a single sentence. |
# | **Simple Lookup/Retrieval** (e.g., "Find the definition of 'quantum entanglement'") | A direct definition |  Complete Retrieval | Vector search is the simplest and most efficient approach. |
#
#
# **3. Using Gen AI SDKs (Cohere, etc.)**
#
# * **Cohere's Approach:** Cohere’s SDKs usually provide a framework for both.  They strongly encourage the use of vector databases for retrieval and then using their LLM for generation.  They provide tools to build the complete pipeline.
# * **Key Considerations:**  Cohere will likely focus on providing the tools to connect these components, emphasizing the speed and efficiency of their vector search and LLM.
#
# **4. Using LlamaIndex (or other LLM Indexes)**
#
# * **LlamaIndex's Role:** LlamaIndex is a *framework* that makes it easier to build any of these approaches.  It provides tools for:
#     * **Data Ingestion:**  Loading and structuring your documents.
#     * **Indexing:**  Creating vector indexes.
#     * **Querying:**  Sending queries to the LLM and retrieving relevant context.
# * **Flexibility:** LlamaIndex is more adaptable. You can experiment with different indexing strategies (e.g., different embeddings models, different ways of chunking your documents) and seamlessly switch between retrieval and chat modes.
#
# **Resources:**
#
# * **Cohere:** [https://cohere.com/](https://cohere.com/)
# * **LlamaIndex:** [https://www.llamaindex.ai/](https://www.llamaindex.ai/)
# * **Pinecone:** [https://www.pinecone.io/](https://www.pinecone.io/) (Vector Database)
#
# To help me give you even more tailored advice, could you tell me:
#
# *   **What kind of data are you working with?** (e.g., legal documents, product descriptions, research papers, customer support conversations, etc.)
# *   **What is the primary goal of your application?** (e.g., answering customer questions, generating reports, summarizing information, creative writing, etc.)
